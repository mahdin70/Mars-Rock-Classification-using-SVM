# %%
# !pip install bing-image-downloader

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader.download("Basalt", limit=100, output_dir='images',adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\MUKIT\Jupyter Notebook\Machine-Learning-Projects\Mars-Rock-Classification\images\Basalt
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.granite-marble-quartz.co.uk/wp-content/uploads/2015/02/basalt-road.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.stoneandgarden.co/media/catalog/product/b/l/black_baslt.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.britannica.com/88/123788-050-9FA53209/Basalt.jpg
# [Error]Invalid image, not saving https://cdn.britannica.com/88/123788-050-9FA53209/Basalt.jpg
#
# [!] Issue getting: https://cdn.britannica.com/88/123788-050-9FA53209/Basalt.jpg
# [!] Error:: Invalid image, not saving https://cdn.britannica.com/88/123788-050-9FA53209/Basalt.jpg
#
# [%] Downloading Image #3 from https://www.eutit.com/files/materialy/img-7909.png
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("Granite", limit=100, output_dir='images',adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\MUKIT\Jupyter Notebook\Machine-Learning-Projects\Mars-Rock-Classification\images\Granite
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://images.homedepot-static.com/productImages/3a1526a4-8e1f-44b9-9315-c13f2ca92b8e/svn/baltic-brown-stonemark-granite-countertop-samples-dt-g704-64_1000.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://upload.wikimedia.org/wikipedia/commons/b/bc/Fjæregranitt3.JPG
# [!] Issue getting: https://upload.wikimedia.org/wikipedia/commons/b/bc/Fjæregranitt3.JPG
# [!] Error:: 'ascii' codec can't encode character '\xe6' in position 30: ordinal not in range(128)
# [%] Downloading Image #2 from http://upload.wikimedia.org/wikipedia/commons/1/19/Itu_granite.JPG
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("Marble", limit=100, output_dir='images',adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\MUKIT\Jupyter Notebook\Machine-Learning-Projects\Mars-Rock-Classification\images\Marble
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.delpretemasonry.com/wp-content/uploads/2016/04/ThinkstockPhotos-478183140.jpg
# [!] Issue getting: http://www.delpretemasonry.com/wp-content/uploads/2016/04/ThinkstockPhotos-478183140.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #1 from https://bordtandsons.com/wp-content/uploads/2014/03/Marble-slab-005.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://bgfons.com/upload/marble_texture4466.jpg
# [Error]Invalid image, not saving http://bgfons.com/upload/marble_texture4466.jpg
#
# [!] Issue getting: http://bgfons.com/upload/marble_texture4466.jpg
# [!] Error:: Invalid image, not saving http://bgfons.com/upload/marble_texture4466.jpg
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("Quartzite", limit=100, output_dir='images',adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\MUKIT\Jupyter Notebook\Machine-Learning-Projects\Mars-Rock-Classification\images\Quartzite
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.gemsociety.org/wp-content/uploads/2014/11/quartzite.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.enterprise-q.co.uk/wp-content/uploads/2014/01/Quartz-rock-crystal.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.thoughtco.com/thmb/GoKJxiKdkdZ9qyxXzNJoM-LAXSU=/768x0/filters:no_upscale():max_bytes(150000):strip_icc()/quartzite-crystal-mineral-sample-studio-shot-with-black-background-972333846-5c7e6525c9e77c0001d19dda.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://reynolds.asu.edu/glg103_online/images/rock_mineral_photos/Quartzite/IMG_2979.JPG
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("Coal", limit=100, output_dir='images',adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\MUKIT\Jupyter Notebook\Machine-Learning-Projects\Mars-Rock-Classification\images\Coal
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.readfearn.com/wp-content/uploads/2014/10/coal.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.usnews.com/cmsmedia/01/b4/7805d4c5463095e19c613f0d216f/151229-coal-stock.jpg
# [!] Issue getting: http://www.usnews.com/cmsmedia/01/b4/7805d4c5463095e19c613f0d216f/151229-coal-stock.jpg
# [!] Error:: timed out
# [%] Downloading Image #2 from https://blueridgecoal.com/wp-content/uploads/2018/01/coal.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://media2.s-nbcnews.com/i/newscms/2018_15/2263201/171215-navajo-coal-jhc-1725_f20a165a7c5c160ed2f88b41c7578200.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://images.hgmsites.net/hug/coal-by-flicker-user-oatsy40-used-under-cc-license_100500949_h.jpg
# ...

# %%
from bing_image_downloader import downloader
downloader.download("Sandstone", limit=100, output_dir='images',adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\MUKIT\Jupyter Notebook\Machine-Learning-Projects\Mars-Rock-Classification\images\Sandstone
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://fthmb.tqn.com/q6mO6D1EChxBop7gOXbzl9D_0rQ=/3982x2506/filters:fill(auto,1)/the-wave-504092572-570877ca3df78c7d9eceb997.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://1.bp.blogspot.com/-t_6FVcD-fM8/WH9xsi5OdRI/AAAAAAAAEYQ/6EysSAdQbR8Bdp8WCq9Y89JfZC18NpEXACLcB/s1600/20080130110622.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://mineralseducationcoalition.org/wp-content/uploads/Sandstone2_56061193.jpg
# [!] Issue getting: https://mineralseducationcoalition.org/wp-content/uploads/Sandstone2_56061193.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #3 from https://www.publicdomainpictures.net/pictures/10000/velka/sandstone-rocks-299412813939346d39.jpg
# ...

# %%
from bing_image_downloader import downloader
downloader.download("Limestone", limit=100, output_dir='images',adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\MUKIT\Jupyter Notebook\Machine-Learning-Projects\Mars-Rock-Classification\images\Limestone
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.pattisonsand.com/wp-content/uploads/2018/10/smallriprap.png
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://ericksonslandscapesupply.com/wp-content/uploads/2014/06/2-Limestone.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://bariteworld.com/wp-content/uploads/2015/11/limestone-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://upload.wikimedia.org/wikipedia/commons/1/10/Brachiopoda-limestone_hg.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://1.bp.blogspot.com/-hTfN0WyMhG4/VQQvxvOkmbI/AAAAAAAAAOY/yJOdt_hU-Ng/s1600/limestone5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://www.dnr.mo.gov/geology/images/fossiliferouslimestonelg.jpg
# ...

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize
import pickle
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import svm
from sklearn.metrics import accuracy_score, confusion_matrix

target = []  # target image
images = []  # sample images
flat_data = []  # flattened data

# Use relative path for Data Directory
DATADIR = 'images'
CATEGORIES = ['Basalt', 'Coal', 'Granite', 'Limestone', 'Marble', 'Quartzite', 'Sandstone']

# %%
for category in CATEGORIES:
    class_num = CATEGORIES.index(category)  # indexing with number label
    path = os.path.join(DATADIR, category)  # creating path to use all the images from the directory
    for img in os.listdir(path):
        img_array = imread(os.path.join(path, img))
        img_resized = resize(img_array, (150, 150, 3))  # resizing all images
        flat_data.append(img_resized.flatten())  # appending flattened images to flat_data array
        images.append(img_resized)
        target.append(class_num)

flat_data = np.array(flat_data)
target = np.array(target)
images = np.array(images)
# Out:
# D:\Software\Anaconda\lib\site-packages\PIL\TiffImagePlugin.py:822: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
#       3 path = os.path.join(DATADIR, category)  # creating path to use all the images from the directory
#       4 for img in os.listdir(path):
# ----> 5     img_array = imread(os.path.join(path, img))
#       6     img_resized = resize(img_array, (150, 150, 3))  # resizing all images
#       7     flat_data.append(img_resized.flatten())  # appending flattened images to flat_data array
#
# File D:\Software\Anaconda\lib\site-packages\skimage\io\_io.py:53, in imread(fname, as_gray, plugin, **plugin_args)
#      50         plugin = 'tifffile'
#      52 with file_or_url_context(fname) as fname:
# ...

# %%
for category in CATEGORIES:
    class_num = CATEGORIES.index(category)  # indexing with number label
    path = os.path.join(DATADIR, category)  # creating path to use all the images from the directory
    for img in os.listdir(path):
        img_array = imread(os.path.join(path, img))
        img_resized = resize(img_array, (150, 150, 3))  # resizing all images
        flat_data.append(img_resized.flatten())  # appending flattened images to flat_data array
        images.append(img_resized)
        target.append(class_num)

flat_data = np.array(flat_data)
target = np.array(target)
images = np.array(images)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
#       3 path = os.path.join(DATADIR, category)  # creating path to use all the images from the directory
#       4 for img in os.listdir(path):
# ----> 5     img_array = imread(os.path.join(path, img))
#       6     img_resized = resize(img_array, (150, 150, 3))  # resizing all images
#       7     flat_data.append(img_resized.flatten())  # appending flattened images to flat_data array
#
# File D:\Software\Anaconda\lib\site-packages\skimage\io\_io.py:53, in imread(fname, as_gray, plugin, **plugin_args)
#      50         plugin = 'tifffile'
#      52 with file_or_url_context(fname) as fname:
# ---> 53     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      55 if not hasattr(img, 'ndim'):
#      56     return img
#
# ...

# %%
# !pip install opencv-python

# %%
from cv2 import imread, resize

# %%
for category in CATEGORIES:
    class_num = CATEGORIES.index(category)  # indexing with number label
    path = os.path.join(DATADIR, category)  # creating path to use all the images from the directory
    for img in os.listdir(path):
        img_array = imread(os.path.join(path, img))
        img_resized = resize(img_array, (150, 150, 3))  # resizing all images
        flat_data.append(img_resized.flatten())  # appending flattened images to flat_data array
        images.append(img_resized)
        target.append(class_num)

flat_data = np.array(flat_data)
target = np.array(target)
images = np.array(images)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
#       4 for img in os.listdir(path):
#       5     img_array = imread(os.path.join(path, img))
# ----> 6     img_resized = resize(img_array, (150, 150, 3))  # resizing all images
#       7     flat_data.append(img_resized.flatten())  # appending flattened images to flat_data array
#       8     images.append(img_resized)
#
# error: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - Can't parse 'dsize'. Expected sequence length 2, got 3
# >  - Can't parse 'dsize'. Expected sequence length 2, got 3

# %%
for category in CATEGORIES:
    class_num = CATEGORIES.index(category)  # indexing with number label
    path = os.path.join(DATADIR, category)  # creating path to use all the images from the directory
    for img in os.listdir(path):
        img_array = imread(os.path.join(path, img))
        img_resized = resize(img_array, (150, 150))  # resizing all images
        flat_data.append(img_resized.flatten())  # appending flattened images to flat_data array
        images.append(img_resized)
        target.append(class_num)

flat_data = np.array(flat_data)
target = np.array(target)
images = np.array(images)

# %%
x_train, x_test, y_train, y_test = train_test_split(flat_data, target, test_size=0.25, random_state=109)

# %%
param_grid = [
    {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
    {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf']},
]

svc = svm.SVC(probability=True)
clf = GridSearchCV(svc, param_grid)
clf.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(probability=True),
#              param_grid=[{'C': [1, 10, 100, 1000], 'kernel': ['linear']},
#                          {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001],
#                           'kernel': ['rbf']}])

# %%
pickle.dump(clf, open('img_model.pkl', 'wb'))

# %%
import sklearn
print("Scikit-learn version in Streamlit environment:", sklearn.__version__)
# Out:
# Scikit-learn version in Streamlit environment: 1.0.2
